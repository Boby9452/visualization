# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
titanic=pd.read_csv("/content/train.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ax=titanic.plot(figsize=(20,10),title='titanic datset')
ax.set_xlabel("X-axis")
ax.set_ylabel("Yaxis")
# Out:
# Text(0, 0.5, 'Yaxis')

# %%
titanic.plot(kind='bar')

# %%
titanic.plot.scatter(x='Parch',y='Fare',c='Survived')

# %%
snr.relplot(x='Pclass',y='Survived',style='Parch',data=titanic)

# %%
round(100*(titanic.Age.isna().sum(axis=0)/len(titanic.index)),2)
# Out:
# 19.87

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
snr.pairplot(data=titanic,x_vars=['Survived','Pclass'],y_vars=['Parch'])

# %%
titanic['Pclass'].plot(kind='hist')

# %%
snr.catplot(x='Pclass',y='Survived',data=titanic,kind='box')

# %%
np.median(titanic.Pclass)
# Out:
# 3.0

# %%
np.min(titanic.Pclass)
# Out:
# 1

# %%
q1=np.quantile(titanic.Pclass,0.25)
print(q1)
q3=np.quantile(titanic.Pclass,0.75)
print(q3)
iqr=q3-q1
print(iqr)
lv=q1-(1.5*iqr)
rv=q3+(1.5*iqr)
print(lv,rv)
np.max(titanic.Pclass)
# Out:
# 2.0
# 3.0
# 1.0
# 0.5 4.5
# 3
