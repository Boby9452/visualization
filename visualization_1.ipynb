# %% [markdown]
# # ASSIGNMENT-1

# %%
import numpy as np
import pandas as pd

# %%
my_data=pd.DataFrame({"Banana":[50,60,70,80,90,100],"Apples":[100,110,120,130,140,150],"Guava":[70,75,80,85,90,95],"Palm":[34,5,6,7,8,98,],"Grapes":[50,67,89,78,65,45]},index=["0","1","2","3","4","5"])
print(my_data)
# Out:
#    Banana  Apples  Guava  Palm  Grapes
# 0      50     100     70    34      50
# 1      60     110     75     5      67
# 2      70     120     80     6      89
# 3      80     130     85     7      78
# 4      90     140     90     8      65
# 5     100     150     95    98      45

# %%
my_data.to_csv("fruits.csv")

# %%
pd.read_csv("/content/fruits.csv")
# Out:
#    Unnamed: 0  Banana  Apples  Guava  Palm  Grapes
# 0           0      50     100     70    34      50
# 1           1      60     110     75     5      67
# 2           2      70     120     80     6      89
# 3           3      80     130     85     7      78
# 4           4      90     140     90     8      65
# 5           5     100     150     95    98      45

# %% [markdown]
# # Linear Graph

# %%
ax=my_data.plot(figsize=(20,10),title='vijay_data')
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
#  From above linear graph we can conclude that graph has is irregular and the graph of apple is somewhat regular as it is a straight line and similar for banana and guava rest has very much irregularity.
#   The maximum value of graph is above 140.

# %% [markdown]
# # BAR GRAPH

# %%
my_data.plot(kind="bar")

# %% [markdown]
# Bar graph shows the price of each fruit in Y-Axis in each row.By this graph we can observe that the apple has the highest price

# %% [markdown]
# # HISTOGRAM

# %%
my_data['Apples'].diff().plot(kind="hist",bins=100)

# %% [markdown]
# #PIE CHART

# %%
my_data.iloc[0].plot.pie(subplots=True,fontsize=10,figsize=(5,5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f03a2cbb450>],
#       dtype=object)

# %% [markdown]
# By pie chart we can find percentage share by each item in particular row or also as a whole.
# Like thus graph shows apple has highest percentage share then guava and banana and grapes are approximately same and palm has the lowest percentage share.
